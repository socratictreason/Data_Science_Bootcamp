# %%
import numpy as np
import matplotlib as plt
import pandas as pd 
from subprocess import check_output
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
from matplotlib.pyplot import figure

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.tail(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
titanic = titanic.drop(columns = ['deck'])

# %%
average = np.mean(titanic['age'])
high = np.max(titanic['age'])
low = np.min(titanic['age'])

# %%
print("average person is " + str(average) + " years old")
print("oldest person is " + str(high) + " years old")
print("youngest person is " + str(low) + " years old")
# Out:
# average person is 29.69911764705882 years old
# oldest person is 80.0 years old
# youngest person is 0.42 years old

# %%
figure(num=None, figsize=(12, 8), dpi=80, facecolor='w', edgecolor='k')
sns.boxplot(titanic['age'])

# %%
sns.boxplot(x='class',y='age',data=titanic,palette='winter')

# %%
sea.barplot(x = 'class', y = 'survived', data= titanic, ci = None)

# %%
sea.barplot(x = 'sex', y = 'survived', data=titanic, ci = None)

# %%
sea.barplot(x = 'embark_town', y = 'survived', data = titanic, ci = None)

# %%
sea.catplot(x = 'class', hue = 'survived', data = titanic, kind = 'count')

# %%
titanic['age'].hist(bins = 10)

# %%
as_fig = sns.FacetGrid(titanic,hue='sex',aspect=5)

as_fig.map(sns.kdeplot,'age',shade=True)

oldest = titanic['age'].max()

as_fig.set(xlim=(0,oldest))

as_fig.add_legend()

# %%
figure(num=None, figsize=(20, 15), dpi=80, facecolor='w', edgecolor='k')
correlation_matrix = titanic.corr().round(2)
fig, ax = plt.subplots(figsize=(20,10))   
sns.heatmap(data=correlation_matrix, annot=True)
